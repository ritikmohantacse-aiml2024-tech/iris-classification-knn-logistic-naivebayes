# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv("Iris.csv")

data.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# ...

# %%
X=data.drop("Species",axis=1)
y=data["Species"]
#y=pd.get_dummies(y,columns=["Species"],drop_first=False)
#y = pd.get_dummies(data["Species"], dtype=int)
y = data["Species"].map({
    "Iris-setosa": 0,
    "Iris-versicolor": 1,
    "Iris-virginica": 2
})
X.head()
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Species, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.5,random_state=42)

# %%
#knn
from sklearn.neighbors import KNeighborsClassifier

knn_classifier=KNeighborsClassifier(n_neighbors=3)
knn_classifier.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
#logistic Regression
from sklearn.linear_model import LogisticRegression
logistic_Regression=LogisticRegression(max_iter=1000)
logistic_Regression.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
#naive bayes
from sklearn.naive_bayes import GaussianNB
NB=GaussianNB()
NB.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred_knn = knn_classifier.predict(X_test)
y_pred_lr = logistic_Regression.predict(X_test)
y_pred_nb = NB.predict(X_test)
print("knn prediction value: ",y_pred_knn)
print("Logistic Regression prediction value: ",y_pred_lr)
print("naive bayes prediction value: ",y_pred_nb)
y_test
# Out:
# knn prediction value:  [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0 0 0 1 0 0 2 1
#  0 0 0 2 1 1 0 0 1 2 2 1 2 1 2 1 0 2 1 0 0 0 1 2 0 0 0 1 0 1 2 0 1 2 0 2 2
#  1]
# Logistic Regression prediction value:  [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0 0 0 1 0 0 2 1
#  0 0 0 2 1 1 0 0 1 2 2 1 2 1 2 1 0 2 1 0 0 0 1 2 0 0 0 1 0 1 2 0 1 2 0 2 2
#  1]
# naive bayes prediction value:  [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0 0 0 1 0 0 2 1
#  0 0 0 2 1 1 0 0 1 2 2 1 2 1 2 1 0 2 1 0 0 0 1 2 0 0 0 1 0 1 2 0 1 2 0 2 2
#  1]
# 73     1
# 18     0
# 118    2
# 78     1
# 76     1
#       ..
# 113    2
# 33     0
# 138    2
# 101    2
# 62     1
# Name: Species, Length: 75, dtype: int64

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score

knn_accuracy = accuracy_score(y_test, y_pred_knn)
knn_precision = precision_score(y_test, y_pred_knn, average="weighted")
knn_recall = recall_score(y_test, y_pred_knn, average="weighted")
knn_f1 = f1_score(y_test, y_pred_knn, average="weighted")

lr_accuracy = accuracy_score(y_test, y_pred_lr)
lr_precision = precision_score(y_test, y_pred_lr, average="weighted")
lr_recall = recall_score(y_test, y_pred_lr, average="weighted")
lr_f1 = f1_score(y_test, y_pred_lr, average="weighted")
knn_accuracy = accuracy_score(y_test, y_pred_knn)

nb_accuracy = accuracy_score(y_test, y_pred_nb)
nb_precision = precision_score(y_test, y_pred_nb, average="weighted")
nb_recall = recall_score(y_test, y_pred_nb, average="weighted")
nb_f1 = f1_score(y_test, y_pred_nb, average="weighted")


comparison = pd.DataFrame({
    "Model": ["KNN", "Logistic Regression", "Naive Bayes"],
    "Accuracy": [knn_accuracy, lr_accuracy, nb_accuracy],
    "Precision": [knn_precision, lr_precision, nb_precision],
    "Recall": [knn_recall, lr_recall, nb_recall],
    "F1-Score": [knn_f1, lr_f1, nb_f1]
})

comparison["Accuracy"] = comparison["Accuracy"] * 100
comparison["Precision"] = comparison["Precision"] * 100
comparison["Recall"] = comparison["Recall"] * 100
comparison["F1-Score"] = comparison["F1-Score"] * 100
print(comparison)
# Out:
#                  Model  Accuracy  Precision  Recall  F1-Score
# 0                  KNN     100.0      100.0   100.0     100.0
# 1  Logistic Regression     100.0      100.0   100.0     100.0
# 2          Naive Bayes     100.0      100.0   100.0     100.0

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

models = {'Logistic Regression': logistic_Regression, 'KNN': knn_classifier, 'Naive Bayes': NB}

for name, model in models.items():
    y_pred = model.predict(X_test)
    print(f"\n{name}")
    print("Accuracy:", accuracy_score(y_test, y_pred))
    
    print("cm:", confusion_matrix(y_test, y_pred))

    print("classification report:", classification_report(y_test, y_pred))
# Out:
# Logistic Regression
# Accuracy: 1.0
# cm: [[29  0  0]
#  [ 0 23  0]
#  [ 0  0 23]]
# classification report:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        29
#            1       1.00      1.00      1.00        23
#            2       1.00      1.00      1.00        23
#
#     accuracy                           1.00        75
#    macro avg       1.00      1.00      1.00        75
# weighted avg       1.00      1.00      1.00        75
#
#
# KNN
# Accuracy: 1.0
# cm: [[29  0  0]
#  [ 0 23  0]
#  [ 0  0 23]]
# classification report:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        29
#            1       1.00      1.00      1.00        23
#            2       1.00      1.00      1.00        23
#
#     accuracy                           1.00        75
#    macro avg       1.00      1.00      1.00        75
# weighted avg       1.00      1.00      1.00        75
#
#
# ...
